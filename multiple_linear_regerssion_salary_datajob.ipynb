# %% [markdown]
# # Linear Regression: Salary prediction for data science jobs

# %% [markdown]
# ## Loading and exploring dataset

# %% [markdown]
# Data Source: https://www.kaggle.com/datasets/hummaamqaasim/jobs-in-data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %%
df_all = pd.read_csv('jobs_in_data.csv')
df_all.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# 0       Full-time       Hybrid          Germany            L
# 1       Full-time    In-person    United States            M
# 2       Full-time    In-person    United States            M
# 3       Full-time    In-person    United States            M
# 4       Full-time    In-person    United States            M

# %%
df_all.shape
# Out:
# (9355, 12)

# %%
df_all.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
df_all.isnull().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %% [markdown]
# ## Analysis Linear Regression

# %%
df_all.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# 0       Full-time       Hybrid          Germany            L
# 1       Full-time    In-person    United States            M
# 2       Full-time    In-person    United States            M
# 3       Full-time    In-person    United States            M
# 4       Full-time    In-person    United States            M

# %%
# get data science job in dataset:
df = df_all[df_all['job_title'] == 'Data Scientist']              
df.head()
# Out:
#     work_year       job_title               job_category salary_currency  \
# 3        2023  Data Scientist  Data Science and Research             USD
# 4        2023  Data Scientist  Data Science and Research             USD
# 5        2023  Data Scientist  Data Science and Research             USD
# 6        2023  Data Scientist  Data Science and Research             USD
# 13       2023  Data Scientist  Data Science and Research             GBP
#
#     salary  salary_in_usd employee_residence experience_level employment_type  \
# 3   212000         212000      United States           Senior       Full-time
# 4    93300          93300      United States           Senior       Full-time
# 5   130000         130000      United States           Senior       Full-time
# 6   100000         100000      United States           Senior       Full-time
# 13   35000          43064     United Kingdom        Mid-level       Full-time
#
#    work_setting company_location company_size
# 3     In-person    United States            M
# 4     In-person    United States            M
# 5        Remote    United States            M
# 6        Remote    United States            M
# 13    In-person   United Kingdom            M

# %%
df = df[df['employment_type'] == 'Full-time']
df.head()
# Out:
#     work_year       job_title               job_category salary_currency  \
# 3        2023  Data Scientist  Data Science and Research             USD
# 4        2023  Data Scientist  Data Science and Research             USD
# 5        2023  Data Scientist  Data Science and Research             USD
# 6        2023  Data Scientist  Data Science and Research             USD
# 13       2023  Data Scientist  Data Science and Research             GBP
#
#     salary  salary_in_usd employee_residence experience_level employment_type  \
# 3   212000         212000      United States           Senior       Full-time
# 4    93300          93300      United States           Senior       Full-time
# 5   130000         130000      United States           Senior       Full-time
# 6   100000         100000      United States           Senior       Full-time
# 13   35000          43064     United Kingdom        Mid-level       Full-time
#
#    work_setting company_location company_size
# 3     In-person    United States            M
# 4     In-person    United States            M
# 5        Remote    United States            M
# 6        Remote    United States            M
# 13    In-person   United Kingdom            M

# %%
df.head()
# Out:
#     work_year       job_title               job_category salary_currency  \
# 3        2023  Data Scientist  Data Science and Research             USD
# 4        2023  Data Scientist  Data Science and Research             USD
# 5        2023  Data Scientist  Data Science and Research             USD
# 6        2023  Data Scientist  Data Science and Research             USD
# 13       2023  Data Scientist  Data Science and Research             GBP
#
#     salary  salary_in_usd employee_residence experience_level employment_type  \
# 3   212000         212000      United States           Senior       Full-time
# 4    93300          93300      United States           Senior       Full-time
# 5   130000         130000      United States           Senior       Full-time
# 6   100000         100000      United States           Senior       Full-time
# 13   35000          43064     United Kingdom        Mid-level       Full-time
#
#    work_setting company_location company_size
# 3     In-person    United States            M
# 4     In-person    United States            M
# 5        Remote    United States            M
# 6        Remote    United States            M
# 13    In-person   United Kingdom            M

# %% [markdown]
# ### Mapping the values of 6 columns 'work_year', 'employee_residence', 'experience_level', 'work_setting', 'company_location', 'company_size':

# %%
df.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
df['employee_residence'].unique()
# Out:
# array(['United States', 'United Kingdom', 'Spain', 'Ireland', 'Canada',
#        'Netherlands', 'Greece', 'Latvia', 'Turkey', 'Italy', 'Andorra',
#        'Ecuador', 'India', 'Uzbekistan', 'France', 'Switzerland',
#        'Germany', 'Austria', 'Brazil', 'Cyprus', 'Romania', 'Mexico',
#        'Australia', 'Belgium', 'Japan', 'Poland', 'Russia', 'Nigeria',
#        'Philippines', 'Serbia', 'Singapore'], dtype=object)

# %%
mymap_1 = {'United States':1, 'United Kingdom':2, 'Spain':3, 'Ireland':4, 'Canada':5,
       'Netherlands':6, 'Greece':7, 'Latvia':8, 'Turkey':9, 'Italy':10, 'Andorra':11,
       'Ecuador':12, 'India':13, 'Uzbekistan':14, 'France':15, 'Switzerland':16,
       'Germany':17, 'Austria':18, 'Brazil':19, 'Cyprus':20, 'Romania':21, 'Mexico':22,
       'Australia':23, 'Belgium':24, 'Japan':25, 'Poland':26, 'Russia':27, 'Nigeria':28,
       'Philippines':29, 'Serbia':30, 'Singapore':31}
df['employee_residence'] = df[['employee_residence']].applymap(lambda s: mymap_1.get(s) if s in mymap_1 else s)

df.head()
# Out:
# C:\Users\MSI Laptop\AppData\Local\Temp\ipykernel_9804\2172000728.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df['employee_residence'] = df[['employee_residence']].applymap(lambda s: mymap_1.get(s) if s in mymap_1 else s)
#     work_year       job_title               job_category salary_currency  \
# 3        2023  Data Scientist  Data Science and Research             USD
# 4        2023  Data Scientist  Data Science and Research             USD
# 5        2023  Data Scientist  Data Science and Research             USD
# 6        2023  Data Scientist  Data Science and Research             USD
# 13       2023  Data Scientist  Data Science and Research             GBP
#
#     salary  salary_in_usd  employee_residence experience_level  \
# 3   212000         212000                   1           Senior
# 4    93300          93300                   1           Senior
# 5   130000         130000                   1           Senior
# 6   100000         100000                   1           Senior
# 13   35000          43064                   2        Mid-level
#
#    employment_type work_setting company_location company_size
# 3        Full-time    In-person    United States            M
# 4        Full-time    In-person    United States            M
# 5        Full-time       Remote    United States            M
# 6        Full-time       Remote    United States            M
# 13       Full-time    In-person   United Kingdom            M

# %%
df['experience_level'].unique()
# Out:
# array(['Senior', 'Mid-level', 'Entry-level', 'Executive'], dtype=object)

# %%
mymap_2 = {'Senior': 1, 'Mid-level': 2, 'Entry-level': 3, 'Executive': 4}
df['experience_level'] = df[['experience_level']].applymap(lambda s: mymap_2.get(s) if s in mymap_2 else s)

df.head()
# Out:
# C:\Users\MSI Laptop\AppData\Local\Temp\ipykernel_9804\1559660339.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df['experience_level'] = df[['experience_level']].applymap(lambda s: mymap_2.get(s) if s in mymap_2 else s)
#     work_year       job_title               job_category salary_currency  \
# 3        2023  Data Scientist  Data Science and Research             USD
# 4        2023  Data Scientist  Data Science and Research             USD
# 5        2023  Data Scientist  Data Science and Research             USD
# 6        2023  Data Scientist  Data Science and Research             USD
# 13       2023  Data Scientist  Data Science and Research             GBP
#
#     salary  salary_in_usd  employee_residence  experience_level  \
# 3   212000         212000                   1                 1
# 4    93300          93300                   1                 1
# 5   130000         130000                   1                 1
# 6   100000         100000                   1                 1
# 13   35000          43064                   2                 2
#
#    employment_type work_setting company_location company_size
# 3        Full-time    In-person    United States            M
# 4        Full-time    In-person    United States            M
# 5        Full-time       Remote    United States            M
# 6        Full-time       Remote    United States            M
# 13       Full-time    In-person   United Kingdom            M

# %%
df['work_setting'].unique()
# Out:
# array(['In-person', 'Remote', 'Hybrid'], dtype=object)

# %%
mymap_3 = {'In-person': 1, 'Remote': 2, 'Hybrid': 3}
df['work_setting'] = df[['work_setting']].applymap(lambda s: mymap_3.get(s) if s in mymap_3 else s)

df.head()
# Out:
# C:\Users\MSI Laptop\AppData\Local\Temp\ipykernel_9804\2258334484.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df['work_setting'] = df[['work_setting']].applymap(lambda s: mymap_3.get(s) if s in mymap_3 else s)
#     work_year       job_title               job_category salary_currency  \
# 3        2023  Data Scientist  Data Science and Research             USD
# 4        2023  Data Scientist  Data Science and Research             USD
# 5        2023  Data Scientist  Data Science and Research             USD
# 6        2023  Data Scientist  Data Science and Research             USD
# 13       2023  Data Scientist  Data Science and Research             GBP
#
#     salary  salary_in_usd  employee_residence  experience_level  \
# 3   212000         212000                   1                 1
# 4    93300          93300                   1                 1
# 5   130000         130000                   1                 1
# 6   100000         100000                   1                 1
# 13   35000          43064                   2                 2
#
#    employment_type  work_setting company_location company_size
# 3        Full-time             1    United States            M
# 4        Full-time             1    United States            M
# 5        Full-time             2    United States            M
# 6        Full-time             2    United States            M
# 13       Full-time             1   United Kingdom            M

# %%
df['company_location'].unique()
# Out:
# array(['United States', 'United Kingdom', 'Spain', 'Ireland', 'Canada',
#        'Netherlands', 'Greece', 'Latvia', 'Poland', 'Italy', 'Andorra',
#        'Ecuador', 'India', 'Switzerland', 'Germany', 'France', 'Brazil',
#        'Estonia', 'Romania', 'Mexico', 'Australia', 'Belgium', 'Turkey',
#        'Malaysia', 'Nigeria', 'Austria', 'Luxembourg', 'Israel'],
#       dtype=object)

# %%
mymap_4 = {'United States':1, 'United Kingdom':2, 'Spain':3, 'Ireland':4, 'Canada':5,
       'Netherlands':6, 'Greece':7, 'Latvia':8, 'Poland':9, 'Italy':10, 'Andorra':11,
       'Ecuador':12, 'India':13, 'Switzerland':14, 'Germany':15, 'France':16, 'Brazil':17,
       'Estonia':18, 'Romania':19, 'Mexico':20, 'Australia':21, 'Belgium':22, 'Turkey':23,
       'Malaysia':24, 'Nigeria':25, 'Austria':26, 'Luxembourg':27, 'Israel':28}
df['company_location'] = df[['company_location']].applymap(lambda s: mymap_4.get(s) if s in mymap_4 else s)

df.head()
# Out:
# C:\Users\MSI Laptop\AppData\Local\Temp\ipykernel_9804\3734990733.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df['company_location'] = df[['company_location']].applymap(lambda s: mymap_4.get(s) if s in mymap_4 else s)
#     work_year       job_title               job_category salary_currency  \
# 3        2023  Data Scientist  Data Science and Research             USD
# 4        2023  Data Scientist  Data Science and Research             USD
# 5        2023  Data Scientist  Data Science and Research             USD
# 6        2023  Data Scientist  Data Science and Research             USD
# 13       2023  Data Scientist  Data Science and Research             GBP
#
#     salary  salary_in_usd  employee_residence  experience_level  \
# 3   212000         212000                   1                 1
# 4    93300          93300                   1                 1
# 5   130000         130000                   1                 1
# 6   100000         100000                   1                 1
# 13   35000          43064                   2                 2
#
#    employment_type  work_setting  company_location company_size
# 3        Full-time             1                 1            M
# 4        Full-time             1                 1            M
# 5        Full-time             2                 1            M
# 6        Full-time             2                 1            M
# 13       Full-time             1                 2            M

# %%
df['company_size'].unique()
# Out:
# array(['M', 'L', 'S'], dtype=object)

# %%
mymap_5 = {'M': 1, 'L': 2, 'S': 3}
df['company_size'] = df[['company_size']].applymap(lambda s: mymap_5.get(s) if s in mymap_5 else s)

df.head()
# Out:
# C:\Users\MSI Laptop\AppData\Local\Temp\ipykernel_9804\524619143.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df['company_size'] = df[['company_size']].applymap(lambda s: mymap_5.get(s) if s in mymap_5 else s)
#     work_year       job_title               job_category salary_currency  \
# 3        2023  Data Scientist  Data Science and Research             USD
# 4        2023  Data Scientist  Data Science and Research             USD
# 5        2023  Data Scientist  Data Science and Research             USD
# 6        2023  Data Scientist  Data Science and Research             USD
# 13       2023  Data Scientist  Data Science and Research             GBP
#
#     salary  salary_in_usd  employee_residence  experience_level  \
# 3   212000         212000                   1                 1
# 4    93300          93300                   1                 1
# 5   130000         130000                   1                 1
# 6   100000         100000                   1                 1
# 13   35000          43064                   2                 2
#
#    employment_type  work_setting  company_location  company_size
# 3        Full-time             1                 1             1
# 4        Full-time             1                 1             1
# 5        Full-time             2                 1             1
# 6        Full-time             2                 1             1
# 13       Full-time             1                 2             1

# %% [markdown]
# ### Linear Regression

# %%
df.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
linear_regression = linear_model.LinearRegression()

#train the model
linear_regression.fit(
    df[['work_year','employee_residence', 'experience_level', 'work_setting' , 'company_location', 'company_size']],
    df['salary_in_usd']
)
# Out:
# LinearRegression()

# %%
w = linear_regression.coef_
b = linear_regression.intercept_

w, b
# Out:
# (array([ 13981.54663119,  -2496.3171379 , -21463.23550619,    567.03343337,
#          -2004.73382929,  -5483.46965997]),
#  -28083348.259296775)

# %% [markdown]
# ### Predict

# %%
linear_regression.predict([[2023, 2, 3, 3, 3, 2]])
# Out:
# c:\Users\MSI Laptop\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([116658.19429658])

# %% [markdown]
# The model predicted a person from United Kingdom, experience is Entry-level, work seting is Hybrid, work in a large company in Spain can receive an annual income of 116659 USD (in Data Science jobs)

# %% [markdown]
#  -- End --
